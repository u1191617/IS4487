# %% [markdown]
# <a href="https://colab.research.google.com/github/u1191617/IS4487/blob/main/Module4_Script_v1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IS 4487 Module 4 Script
#
# ## Objectives
#
# *   Deal with nulls
# *   Standardize/transform attributes
# *   Convert attributes to factors (categories)
# *   Encode attributes

# %% [markdown]
# ##Load Libraries
#
# In this class we will be using
# - Pandas
# - Scikitlearn
# - Matplotlib

# %%
import pandas as pd
import matplotlib as mpl
import numpy as np

from sklearn.tree import DecisionTreeClassifier, export_graphviz # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn import tree

# %% [markdown]
# ## Getting data into Pandas
#
# In this case we will load data from the statsmodels.org library
#
# See the Canvas assignments and lectures for a description of the Megatelco data
#
# **Note:** you will need to enter a code supplied by Google in the next step.

# %%
from google.colab import drive 
drive.mount('/content/gdrive', force_remount=True)

df = pd.read_csv (r'/content/gdrive/MyDrive/Colab Notebooks/adviseinvest.csv')
# Out:
# Mounted at /content/gdrive

# %%
#look at the top rows
df.head(10)
# Out:
#    answered  income  female  age  job  num_dependents  rent  own_res  new_car  \
# 0         1   13520       0   23    0               1     1        0      0.0
# 1         0   14780       0   22    2               1     0        1      0.0
# 2         1   37570       0   62    2               1     0        0      1.0
# 3         0   12450       0   33    2               1     0        1      0.0
# 4         0   12400       0   48    1               2     0        0      1.0
# 5         1   14030       0   28    2               1     1        0      1.0
# 6         1    9320       0   24    2               1     0        1      0.0
# 7         1   11750       0   68    0               1     0        0      1.0
# 8         1   69670       0   36    3               1     1        0      0.0
# 9         1    3380       0   52    2               1     0        1      0.0
#
#    chk_acct  sav_acct  num_accts  mobile  product
# 0         0         2          0       1        2
# ...

# %%
#look at the datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29504 entries, 0 to 29503
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   answered        29504 non-null  int64
#  1   income          29504 non-null  int64
#  2   female          29504 non-null  int64
#  3   age             29504 non-null  int64
#  4   job             29504 non-null  int64
#  5   num_dependents  29504 non-null  int64
#  6   rent            29504 non-null  int64
#  7   own_res         29504 non-null  int64
#  8   new_car         29502 non-null  float64
#  9   chk_acct        29504 non-null  int64
#  10  sav_acct        29504 non-null  int64
#  11  num_accts       29504 non-null  int64
#  12  mobile          29504 non-null  int64
#  13  product         29504 non-null  int64
# dtypes: float64(1), int64(13)
# memory usage: 3.2 MB

# %%
#describe the data before cleaning it
df.describe()
# Out:
#            answered         income        female           age           job  \
# count  29504.000000   29504.000000  29504.000000  29504.000000  29504.000000
# mean       0.546638   33766.893303      0.054230     34.770065      1.915401
# std        0.497829   29379.202710      0.226475     11.355777      0.658183
# min        0.000000  -65600.000000      0.000000     19.000000      0.000000
# 25%        0.000000   13550.000000      0.000000     26.000000      2.000000
# 50%        1.000000   23310.000000      0.000000     32.000000      2.000000
# 75%        1.000000   41690.000000      0.000000     40.000000      2.000000
# max        1.000000  159450.000000      1.000000     74.000000      3.000000
#
#        num_dependents          rent       own_res       new_car      chk_acct  \
# count    29504.000000  29504.000000  29504.000000  29502.000000  29504.000000
# mean         1.140998      0.210412      0.681128      0.240797      1.468547
# ...

# %% [markdown]
# ## Clean up the data

# %%
#Remove rows with NA's
df_clean = df_clean.dropna() 

#Remove negative income value and outlier in num_accts
df_clean = df[(df['income'] > 0) & (df['num_accts'] < 1000)]



df_clean.describe()
# Out:
#            answered         income        female           age           job  \
# count  29501.000000   29501.000000  29501.000000  29501.000000  29501.000000
# mean       0.546626   33772.036880      0.054168     34.769601      1.915427
# std        0.497830   29373.597165      0.226352     11.355150      0.658194
# min        0.000000    2760.000000      0.000000     19.000000      0.000000
# 25%        0.000000   13550.000000      0.000000     26.000000      2.000000
# 50%        1.000000   23310.000000      0.000000     32.000000      2.000000
# 75%        1.000000   41690.000000      0.000000     40.000000      2.000000
# max        1.000000  159450.000000      1.000000     74.000000      3.000000
#
#        num_dependents          rent       own_res       new_car      chk_acct  \
# count    29501.000000  29501.000000  29501.000000  29499.000000  29501.000000
# mean         1.141012      0.210434      0.681096      0.240788      1.468459
# ...

# %% [markdown]
# # Convert variables to factors
#
# - job
# - product
# - chk_accts
# - sav_acct

# %%
#Convert variables into factors 
df_clean['job'] = df_clean['job'].astype('category')
df_clean['product'] = df_clean['product'].astype('category')
df_clean['chk_accts'] = df_clean['chk_acct'].astype('category')
df_clean['sav_accts'] = df_clean['sav_acct'].astype('category')

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29501 entries, 0 to 29503
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   answered        29501 non-null  int64
#  1   income          29501 non-null  int64
#  2   female          29501 non-null  int64
#  3   age             29501 non-null  int64
#  4   job             29501 non-null  category
#  5   num_dependents  29501 non-null  int64
#  6   rent            29501 non-null  int64
#  7   own_res         29501 non-null  int64
#  8   new_car         29499 non-null  float64
#  9   chk_acct        29501 non-null  int64
#  10  sav_acct        29501 non-null  int64
#  11  num_accts       29501 non-null  int64
#  12  mobile          29501 non-null  int64
#  13  product         29501 non-null  category
#  14  chk_accts       29501 non-null  category
#  15  sav_accts       29501 non-null  category
# dtypes: category(4), float64(1), int64(11)
# ...
